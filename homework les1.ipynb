# %%
import numpy as np
import matplotlib.pyplot as plt
values = np.array([70,85,90,65,78,88,75,82,79,93])
print(np.mean(values))
print(np.max(values))
print(np.min(values))
print(np.median(values))
# Out:
# 80.5
# 93
# 65
# 80.5

# %%
plt.hist(values)
plt.show()
